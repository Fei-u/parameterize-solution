# %%
from libs import *
from train import *
from PDEs import Heat
from plot import *

# %%
from NNs import FNN

layer_size = [3] + [100]*5 + [1]
net = FNN.net(layer_size=layer_size)

model = Heat.equation(net, 4, 1, 1)

Train = Train(net, model, batch_size=2**8)
Train.train(epoch=10**5, lr=0.0001)

torch.save(net, 'net_model.pkl')

errors = Train.get_errors()

error_plt(errors)
# Out:
# Epoch 500 - lr 0.0001 -  loss: 50.747589569091794
# Epoch 1000 - lr 0.0001 -  loss: 47.511301879882815
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1832\26639108.py in <module>
#       7
#       8 Train = Train(net, model, batch_size=2**8)
# ----> 9 Train.train(epoch=10**5, lr=0.0001)
#      10
#      11 torch.save(net, 'net_model.pkl')
#
# c:\Users\12462\OneDrive\桌面\学习\pinn\train.py in train(self, epoch, lr)
#      28         for i in range(epoch):
#      29             optimizer.zero_grad()
# ---> 30             loss = self.model.loss_func(self.batch_size)
#      31             avg_loss = avg_loss + float(loss.item())
#      32             loss.backward()
#
# c:\Users\12462\OneDrive\桌面\学习\pinn\PDEs\Heat.py in loss_func(self, size)
#      45         bd_right_error = (self.net(x_boundary_2)) ** 2
#      46         bd_up_error = (self.net(x_boundary_3)) ** 2
# ---> 47         bd_down_error = (self.net(x_boundary_4)) ** 2
#      48
#      49         return torch.mean(diff_error + init_error + bd_left_error + bd_right_error + bd_up_error + bd_down_error)
#
# ~\.conda\envs\pinn\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# c:\Users\12462\OneDrive\桌面\学习\pinn\NNs\FNN.py in forward(self, x)
#      25
#      26     def forward(self, x):
# ---> 27         return self.layer(x)
#      28
#      29
#
# ~\.conda\envs\pinn\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\.conda\envs\pinn\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~\.conda\envs\pinn\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\.conda\envs\pinn\lib\site-packages\torch\nn\modules\activation.py in forward(self, input)
#     297
#     298     def forward(self, input: Tensor) -> Tensor:
# --> 299         return torch.sigmoid(input)
#     300
#     301
#
# KeyboardInterrupt:

# %%
from NNs import ResNN_F

net = ResNN_F.net(3, ResNN_F.basic_block, 100)
#收敛慢，震荡？？

model = Heat(net, 4, 1, 1)

Train = Train(net, model, batch_size=2**8)
Train.train(epoch=10**5, lr=0.0001)

torch.save(net, 'net_model.pkl')

errors = Train.get_errors()

error_plt(errors)
