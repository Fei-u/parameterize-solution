# %%
from libs import *
from train import *
from PDEs import Heat
from plot import *

# %%
from NNs import FNN

layer_size = [3] + [100]*5 + [1]
net = FNN.net(layer_size=layer_size)
net.to(device)

model = Heat.equation(net, 4, 1, 1)

Train = Train(net, model, batch_size=2**8)
Train.train(epoch=10**5, lr=0.0001)

torch.save(net, 'net_model.pkl')

errors = Train.get_errors()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8028\3095456795.py in <module>
#       7 model = Heat.equation(net, 4, 1, 1)
#       8
# ----> 9 Train = Train(net, model, batch_size=2**8)
#      10 Train.train(epoch=10**5, lr=0.0001)
#      11
#
# TypeError: 'Train' object is not callable

# %%
from NNs import ResNN_F

net = ResNN_F.net(3, ResNN_F.basic_block, 100)
#收敛慢，震荡？？

model = Heat(net, 4, 1, 1)

Train = Train(net, model, batch_size=2**8)
Train.train(epoch=10**5, lr=0.0001)

torch.save(net, 'net_model.pkl')

errors = Train.get_errors()

error_plt(errors)
